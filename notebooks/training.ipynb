# %%
# !git clone https://github.com/KiRzEa/ITS.git
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:7d50d193-f962-4d50-9a38-08b8e9e63bba
